# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

def plot(img):
    plt.imshow(img, "gray")
image = cv2.imread("dark.jpg", 0)
plot(image)

# %%
print(image.shape, image.size, image.dtype)
# Out:
# (194, 259) 50246 uint8

# %%
cloud = image[156:168, 25:50]
image[10:22, 100:125] = cloud
plot(image)
